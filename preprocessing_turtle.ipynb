# %%
import os
import shutil

def convert_polygon_to_bbox(polygon):
    # Extract the x and y coordinates
    x_coords = [point[0] for point in polygon]
    y_coords = [point[1] for point in polygon]
    
    # Calculate min and max for x and y (bounding box)
    min_x = min(x_coords)
    max_x = max(x_coords)
    min_y = min(y_coords)
    max_y = max(y_coords)
    
    # Convert to YOLO format (relative to image size)
    center_x = (min_x + max_x) / 2
    center_y = (min_y + max_y) / 2
    width = max_x - min_x
    height = max_y - min_y
    
    return center_x, center_y, width, height

def process_label_file(label_file_path, output_label_file_path):
    # Read the label file
    with open(label_file_path, 'r') as file:
        lines = file.readlines()

    # Open the output label file for writing
    with open(output_label_file_path, 'w') as output_file:
        for line in lines:
            # Split the line to get the polygon coordinates
            coordinates = list(map(float, line.strip().split()))

            # Convert polygon coordinates to bounding box (4 values)
            polygon = [(coordinates[i], coordinates[i + 1]) for i in range(1, len(coordinates), 2)]
            center_x, center_y, width, height = convert_polygon_to_bbox(polygon)

            # Write the new label in YOLO format: class_id center_x center_y width height
            output_file.write(f"0 {center_x} {center_y} {width} {height}\n")  # Assuming '0' as the class id

def process_labels_in_directory(labels_directory, output_directory):
    # Ensure the output directory exists
    os.makedirs(output_directory, exist_ok=True)

    # Process all label files in the directory
    for label_file in os.listdir(labels_directory):
        label_file_path = os.path.join(labels_directory, label_file)
        output_label_file_path = os.path.join(output_directory, label_file)

        if os.path.isfile(label_file_path):
            process_label_file(label_file_path, output_label_file_path)
            print(f"Processed: {label_file}")

def copy_images_for_test(images_directory, labels_directory, output_test_image_dir, output_test_label_dir, step=10):
    # Ensure the test directories exist
    os.makedirs(output_test_image_dir, exist_ok=True)
    os.makedirs(output_test_label_dir, exist_ok=True)
    
    image_files = sorted(os.listdir(images_directory))  # Ensure images are in order
    
    # Select every tenth image
    selected_images = image_files[::step]  # Step is the interval (10 in this case)
    
    for image_file in selected_images:
        image_path = os.path.join(images_directory, image_file)
        label_path = os.path.join(labels_directory, image_file.replace(".jpg", ".txt"))
        
        # Copy the image to the test folder
        if os.path.isfile(image_path):
            shutil.copy(image_path, os.path.join(output_test_image_dir, image_file))
        
        # Copy the corresponding label to the test folder
        if os.path.isfile(label_path):
            shutil.copy(label_path, os.path.join(output_test_label_dir, image_file.replace(".jpg", ".txt")))

        print(f"Copied: {image_file}")

# Set paths to your dataset directories
train_images_dir = r".\Data\turtles-dataset\train\images"
train_labels_dir = r".\Data\turtles-dataset\train\labels"
valid_labels_dir = r".\Data\turtles-dataset\valid\labels"
output_train_labels_dir = r".\Data\turtles-dataset\train\labels"  # Same folder as the old labels, will be renamed
output_valid_labels_dir = r".\Data\turtles-dataset\valid\labels"

# New paths for the test set
output_test_images_dir = r".\Data\turtles-dataset\test\images"
output_test_labels_dir = r".\Data\turtles-dataset\test\labels"

# Rename the old labels folder to old_labels
if os.path.exists(train_labels_dir):
    os.rename(train_labels_dir, train_labels_dir + "_old")
if os.path.exists(valid_labels_dir):
    os.rename(valid_labels_dir, valid_labels_dir + "_old")

# Process the train and validation label directories
process_labels_in_directory(train_labels_dir + "_old", output_train_labels_dir)
process_labels_in_directory(valid_labels_dir + "_old", output_valid_labels_dir)

# Copy every tenth image and label to the test folder
copy_images_for_test(train_images_dir, train_labels_dir + "_old", output_test_images_dir, output_test_labels_dir, step=10)

print("All label files processed and test set created successfully!")
# Out:
# Processed: red_ear-1-_jpg.rf.00fa191851017fd52ffd086d13f107c9.txt
# Processed: red_ear-1-_jpg.rf.7c36f39354ef4d003a0cbb3d3a36fcc2.txt
# Processed: red_ear-10-_jpg.rf.11c0ef6e52bc32071850e9cc882015b0.txt
# Processed: red_ear-10-_jpg.rf.6313f5be3eecf9dbc504a741efab6d75.txt
# Processed: red_ear-11-_jpg.rf.a5a9609467d44dc8f5677896ea6f80ed.txt
# Processed: red_ear-11-_jpg.rf.ecdac012d7dee5a27485ab3ac3057e56.txt
# Processed: red_ear-12-_jpg.rf.6b6b9c0b9ca5aa80997e9e78b85587bd.txt
# Processed: red_ear-12-_jpg.rf.7d1935667e75c352a4009c7521af0f68.txt
# Processed: red_ear-14-_jpg.rf.286f0cf6d361aa8eb407c4cab96fa464.txt
# Processed: red_ear-15-_jpg.rf.babc2c2aeecb6d0ceace8b0473a3ec82.txt
# Processed: red_ear-16-_jpg.rf.a011b33ab2ea593fbae888412ae56e79.txt
# Processed: red_ear-16-_jpg.rf.b438cc38cbad7962aecb05e37ebd9422.txt
# Processed: red_ear-17-_jpg.rf.262e057e4247b484c294192b9d996da3.txt
# Processed: red_ear-17-_jpg.rf.c8e625816acd7cd99d89930b37885c4a.txt
# Processed: red_ear-18-_jpg.rf.5b697274ca9cb3d76c4fd6845fcd1582.txt
# Processed: red_ear-18-_jpg.rf.fb2a82e26f922bb641bc2e60149fd979.txt
# Processed: red_ear-19-_JPG.rf.a0b4ebfdaed84837448657859d254112.txt
# Processed: red_ear-2-_jpg.rf.3dd8c5d228d4dff5f7a73514f2e1ad85.txt
# Processed: red_ear-2-_jpg.rf.a4024b6dab01332d7d4d321a71562031.txt
# Processed: red_ear-20-_JPG.rf.553d3a22516d81b75838f9f5818a3311.txt
# Processed: red_ear-20-_JPG.rf.ff1d2141933ce0b9f602651ce40f0e2d.txt
# Processed: red_ear-21-_jpg.rf.45c0280c12488684cc8aa2245052eb74.txt
# Processed: red_ear-21-_jpg.rf.d22ead7888199891285e3521e8f94b59.txt
# Processed: red_ear-23-_jpg.rf.6149a6336b6283ac1dc540dffedfdecd.txt
# Processed: red_ear-23-_jpg.rf.ef70e24c225585bdd934df2b5a2a6a41.txt
# Processed: red_ear-24-_jpg.rf.3ebb364a639358b50a42a4d915cfff4e.txt
# Processed: red_ear-24-_jpg.rf.dfa136890f9b57dc38c1495bcbd88223.txt
# Processed: red_ear-25-_jpg.rf.43e3c27d54ff47b871a440367dff5dac.txt
# Processed: red_ear-25-_jpg.rf.8c837e9b7eb72c9897475e73562962c1.txt
# Processed: red_ear-26-_jpg.rf.3a3a68ed9f75652613cdd0135d86da88.txt
# Processed: red_ear-26-_jpg.rf.593e4af51b36f2528f2067f8fb203a2b.txt
# Processed: red_ear-27-_jpg.rf.77972dafe13de448c2ce068535d3cbf1.txt
# Processed: red_ear-27-_jpg.rf.b8af96640fcc3acb122292f059dab1b2.txt
# Processed: red_ear-29-_jpg.rf.538271d28940bf1809e0800418027cfb.txt
# Processed: red_ear-3-_jpg.rf.fa517c4141b11fb2d5cbfff3fea3fcc2.txt
# Processed: red_ear-4-_jpg.rf.48909fe9eaca79779876a9519460a622.txt
# Processed: red_ear-4-_jpg.rf.a46806ea895455bcafab62825c4e036e.txt
# Processed: red_ear-5-_jpg.rf.77ddab6a3ffc48fb7b9979560e3bcb27.txt
# Processed: red_ear-5-_jpg.rf.95142504e803022bb25008efeb7f141e.txt
# Processed: red_ear-6-_jpg.rf.53ac1b49f449356e824beb381c173387.txt
# Processed: red_ear-6-_jpg.rf.a9a91ca9831279d2c9112d368d76e324.txt
# Processed: red_ear-7-_jpg.rf.030e8e8eaba0285775eb937ea4d4c9d5.txt
# Processed: snapping-1-_jpg.rf.28e08a3624528f7213e4ca80ba40f561.txt
# Processed: snapping-1-_jpg.rf.e7b57a632387eba697c7ccd42117c9a8.txt
# Processed: snapping-10-_jpg.rf.964ad002823bf075e562ab508b6e1437.txt
# Processed: snapping-10-_jpg.rf.ba2efa53182c35adb5de8a2917f18944.txt
# Processed: snapping-11-_jpg.rf.717dd6eb337cdbbeb86a9b9ecff77aac.txt
# Processed: snapping-11-_jpg.rf.de81fa7d6120b63012de4bb88784447f.txt
# Processed: snapping-12-_jpg.rf.a190af452d958f509d593af91c666343.txt
# Processed: snapping-12-_jpg.rf.bc5981c7c1e9cec95841bc982d37bc68.txt
# Processed: snapping-14-_jpg.rf.fd3c4ab80815029cb5017c8dab027388.txt
# Processed: snapping-15-_jpg.rf.1ea9d08af21f4c9dd4276ef31510bffb.txt
# Processed: snapping-15-_jpg.rf.4f167a81622a93e340c16f919a1ee4e6.txt
# Processed: snapping-16-_jpg.rf.8b1b7e05bdcaefdea5cc21e4f08a3c66.txt
# Processed: snapping-17-_jpg.rf.6bcf1c328c2bde70c46cb5902e63f148.txt
# Processed: snapping-17-_jpg.rf.e9446266e33497662ec4eaf9b6539425.txt
# Processed: snapping-18-_jpg.rf.41c5242851d4a3cdea44d45e687e843b.txt
# Processed: snapping-19-_jpg.rf.7ed51e581a204b1caf95fc152297c4d7.txt
# Processed: snapping-19-_jpg.rf.fe385b7c6af682b2dc4e5f926f845550.txt
# Processed: snapping-2-_jpg.rf.4597f2bd49d51e6dfcf7e68f167ed475.txt
# Processed: snapping-20-_jpg.rf.2487f47cff884d421432d512fda8102b.txt
# Processed: snapping-20-_jpg.rf.adb4121e4a40fcdd339dd4267785c14b.txt
# Processed: snapping-21-_jpg.rf.f44341dd9710914297114cfd745cf027.txt
# Processed: snapping-21-_jpg.rf.f7b46acc4d9bf812605a7016655acb42.txt
# Processed: snapping-23-_JPG.rf.53418ba2e839795a0baa1c18986e19c1.txt
# Processed: snapping-25-_jpg.rf.3c474ef1511de1ec800d1d5e19372e64.txt
# Processed: snapping-25-_jpg.rf.cba960c47d9ad964c0d14d6024ca53bf.txt
# Processed: snapping-26-_jpg.rf.b2001876a345ec12acf3c03867bb3e0a.txt
# Processed: snapping-27-_jpg.rf.1ab46786131013c27523fa1592aa3d2d.txt
# Processed: snapping-27-_jpg.rf.2d2a900ec6520ecf77264d4615fb10aa.txt
# Processed: snapping-28-_JPG.rf.e04e99cb3023493280559df859c90e3c.txt
# Processed: snapping-28-_JPG.rf.e79a92472b9e220810e0c873dc69f95b.txt
# Processed: snapping-29-_jpg.rf.35507733742279c79145c06990d6d3db.txt
# Processed: snapping-29-_jpg.rf.e77ee5d74f24905ebbd6cba02d24936a.txt
# Processed: snapping-3-_jpg.rf.375225999d3a2c19a1044e9a0c590357.txt
# Processed: snapping-3-_jpg.rf.40ff45b881baba2f2f31e90d1a6a9e4e.txt
# Processed: snapping-4-_jpg.rf.6c323ad5bf647e9035ef98cf286ab9c5.txt
# Processed: snapping-4-_jpg.rf.828c8476c50401ef9c12610a9eb16348.txt
# Processed: snapping-6-_jpg.rf.9fdb3c3babf9fabb080a890ddbf84516.txt
# Processed: snapping-6-_jpg.rf.d5119e0a4c2174f3a0e0809b7c296cad.txt
# Processed: snapping-8-_jpg.rf.76ef81b45a398fd7f195cbc51bbdb4ee.txt
# Processed: snapping-8-_jpg.rf.abeb296e4072462a23d14a4fb381b523.txt
# Processed: snapping-9-_jpg.rf.a2ad262a3e9f654cbe3b6d32b3af314b.txt
# Processed: snapping-9-_jpg.rf.c2853676a8ff4e94edf505fbda9e9f4e.txt
# Processed: red_ear-13-_jpg.rf.1efa35bf89abb986f2d9df4b51226568.txt
# Processed: red_ear-22-_jpg.rf.a87f86df48774abfea7df40958ba8953.txt
# Processed: red_ear-28-_jpg.rf.4320afb2d7d91bd4e2e9fdd419d3cb86.txt
# Processed: red_ear-30-_jpg.rf.d21efd8caf25451cb5e3ae2e12acf6ba.txt
# Processed: red_ear-8-_jpg.rf.25696333e72ce0d7197d2a4fe79e8068.txt
# Processed: red_ear-9-_jpg.rf.3ce8228641e292a9b2be818f88cb89f1.txt
# Processed: snapping-13-_jpg.rf.65da3a5d197219070c61d70ed98d3640.txt
# Processed: snapping-22-_jpg.rf.3b83a75b8f921e19de4e4ca074ba3519.txt
# Processed: snapping-24-_jpg.rf.9346154ee1db0d1fa6fd71727f7582dc.txt
# Processed: snapping-30-_jpg.rf.715e3f55c9690b1e555337926d0f5161.txt
# Processed: snapping-5-_jpg.rf.7f596b710b68d09beae15dd7d3a9ceed.txt
# Processed: snapping-7-_jpg.rf.5925d5b284594fa2e3fce001e3d15e4f.txt
# Copied: red_ear-1-_jpg.rf.00fa191851017fd52ffd086d13f107c9.jpg
# Copied: red_ear-16-_jpg.rf.a011b33ab2ea593fbae888412ae56e79.jpg
# Copied: red_ear-20-_JPG.rf.ff1d2141933ce0b9f602651ce40f0e2d.jpg
# Copied: red_ear-26-_jpg.rf.593e4af51b36f2528f2067f8fb203a2b.jpg
# Copied: red_ear-6-_jpg.rf.a9a91ca9831279d2c9112d368d76e324.jpg
# Copied: snapping-14-_jpg.rf.fd3c4ab80815029cb5017c8dab027388.jpg
# Copied: snapping-20-_jpg.rf.2487f47cff884d421432d512fda8102b.jpg
# Copied: snapping-28-_JPG.rf.e04e99cb3023493280559df859c90e3c.jpg
# Copied: snapping-8-_jpg.rf.76ef81b45a398fd7f195cbc51bbdb4ee.jpg
# All label files processed and test set created successfully!
